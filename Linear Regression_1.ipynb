# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50) # 50 points between 0 and 5
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y, label="scatter plot") # Scatter plot of points
plt.plot(x, 1.2*x+0.8, 'r', label="Line: y = 1.2x + 0.8") # Red line
# Add labels and legend
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
# Display the plot
plt.show()

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50) #0.6*noise五十個點
print(y)
# Out:
# [0.29080947 1.2492021  1.74827509 0.81857614 0.37549411 1.31467287
#  1.17332888 1.6843743  2.35193334 1.0250166  2.05392358 2.15946868
#  1.29044694 3.12436128 3.28929213 3.06362616 1.84223025 2.9992927
#  2.56239021 3.42155909 3.71191544 3.20371195 3.097594   3.28621923
#  3.39148451 3.80072958 4.42391178 3.58268972 4.49855411 4.47612746
#  4.52599451 4.14571956 3.99483767 6.79387657 5.06758171 4.97676363
#  5.29553022 4.60769037 5.89964684 5.03509742 5.23256406 5.86807029
#  5.43853006 5.38018675 5.4297687  5.85647326 6.69032885 5.30218257
#  6.30047088 6.57351131]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')
# Display the plot
plt.show()

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape) #if there's only one number, it means it's 1 dimension
#reshape
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.82246249 0.93887303 1.05528357 1.17169411 1.28810465 1.40451519
#  1.52092574 1.63733628 1.75374682 1.87015736 1.9865679  2.10297844
#  2.21938898 2.33579952 2.45221006 2.5686206  2.68503114 2.80144168
#  2.91785222 3.03426276 3.15067331 3.26708385 3.38349439 3.49990493
#  3.61631547 3.73272601 3.84913655 3.96554709 4.08195763 4.19836817
#  4.31477871 4.43118925 4.54759979 4.66401033 4.78042088 4.89683142
#  5.01324196 5.1296525  5.24606304 5.36247358 5.47888412 5.59529466
#  5.7117052  5.82811574 5.94452628 6.06093682 6.17734736 6.2937579
#  6.41016845 6.52657899]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.3126851547943996

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.1408233])

# %%
b=regr.intercept_ #截距
b
# Out:
# 0.822462491282085

# %%
Y
# Out:
# array([0.82246249, 0.93887303, 1.05528357, 1.17169411, 1.28810465,
#        1.40451519, 1.52092574, 1.63733628, 1.75374682, 1.87015736,
#        1.9865679 , 2.10297844, 2.21938898, 2.33579952, 2.45221006,
#        2.5686206 , 2.68503114, 2.80144168, 2.91785222, 3.03426276,
#        3.15067331, 3.26708385, 3.38349439, 3.49990493, 3.61631547,
#        3.73272601, 3.84913655, 3.96554709, 4.08195763, 4.19836817,
#        4.31477871, 4.43118925, 4.54759979, 4.66401033, 4.78042088,
#        4.89683142, 5.01324196, 5.1296525 , 5.24606304, 5.36247358,
#        5.47888412, 5.59529466, 5.7117052 , 5.82811574, 5.94452628,
#        6.06093682, 6.17734736, 6.2937579 , 6.41016845, 6.52657899])

# %%
#可以將新的x資料帶入算出結果
W*3+b
# Out:
# array([4.24493239])

# %%
y
# Out:
# array([0.29080947, 1.2492021 , 1.74827509, 0.81857614, 0.37549411,
#        1.31467287, 1.17332888, 1.6843743 , 2.35193334, 1.0250166 ,
#        2.05392358, 2.15946868, 1.29044694, 3.12436128, 3.28929213,
#        3.06362616, 1.84223025, 2.9992927 , 2.56239021, 3.42155909,
#        3.71191544, 3.20371195, 3.097594  , 3.28621923, 3.39148451,
#        3.80072958, 4.42391178, 3.58268972, 4.49855411, 4.47612746,
#        4.52599451, 4.14571956, 3.99483767, 6.79387657, 5.06758171,
#        4.97676363, 5.29553022, 4.60769037, 5.89964684, 5.03509742,
#        5.23256406, 5.86807029, 5.43853006, 5.38018675, 5.4297687 ,
#        5.85647326, 6.69032885, 5.30218257, 6.30047088, 6.57351131])
